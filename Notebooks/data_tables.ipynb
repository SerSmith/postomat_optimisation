# %%
import os
import re
from typing import List, Optional
from warnings import warn
import pandas as pd
import numpy as np
from tqdm import tqdm
from shapely.geometry import Polygon
pd.set_option('display.max_columns', None)
tqdm.pandas()

# %%
import psycopg2
from psycopg2 import OperationalError

def create_connection(db_name,
                      db_user,
                      db_password,
                      db_host,
                      db_port):
    connection = None
    try:
        connection = psycopg2.connect(
            database=db_name,
            user=db_user,
            password=db_password,
            host=db_host,
            port=db_port,
        )
        print("Connection to PostgreSQL DB successful")
    except OperationalError as e:
        print(f"The error '{e}' occurred")
    return connection

connection = create_connection(
    "postgres", "root", "Optimists1!", "178.170.192.244", "5432"
)
# Out:
# Connection to PostgreSQL DB successful

# %%
def get_filenames_from_dir(path: str,
                          mandatory_substr: str='',
                          include_subdirs: bool=True,
                          file_extensions: Optional[List[str]]=None):
    """Получает пути к файлам с данными из директории и поддиректорий

    Args:
        path (str): путь к корневому каталогу с файлами
        mandatory_substr (str): обязательная подстрока, которая должна содержаться в имени файла
        include_subdirs (bool, optional):смотреть ли в поддиректориях. Defaults to True.
        file_extensions (str or [str], optional): какие расширения нас интересуют. Defaults to None.

    Returns:
        [str]: список путей к файлам
    """
    files_list = []

    if include_subdirs:
        for root, _, files in os.walk(path):
            files_list += [os.path.join(root, f) for f in files if os.path.isfile(os.path.join(root, f))]
    else:
        files_list = [os.path.join(path, f) for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

    if file_extensions is not None:
        files_list = [f for f in files_list if f.split('.')[-1] in file_extensions]

    files_list = [f for f in files_list if mandatory_substr in f]

    return files_list

# %%
GEODATA_COL = 'GEODATA'
GEODATA_CENTER_COL = 'GEODATA_CENTER'
GEO_COLS = [GEODATA_COL, GEODATA_CENTER_COL]
KAD_NUM_COLS = ['KAD_N', 'KAD_ZU']


def create_geolist(geo_str):
    geo_list = re.sub(r'[^0-9,.]', '', str(geo_str)).split(',')
    if geo_list != []:
        geo_list = [[float(geo_list[i]), float(geo_list[i+1])] for i in range(0, len(geo_list)-1, 2)]
    return geo_list


def prepare_geo(geodata: str) -> str:
    geodata = re.sub(r'[^\[\]0-9,.]', '', str(geodata))
    return geodata.strip(',')


def prepare_kad_num(kad_num: str) -> str:
    kad_num = re.sub(r'[^0-9\:]', '', str(kad_num))
    if (kad_num!='' and kad_num[0]==':'):
        return kad_num[1:]
    return kad_num


def calc_polygon_centroid(coords):
    if not isinstance(coords, list):
        warn('coords is not list')
        return np.nan
    if coords==[]:
        warn('coords is empty')
        return np.nan
    plgn = Polygon(coords)
    return list(plgn.centroid.coords)[0]


def prepare_data_mos_ru(data,
                        geodata_col: str=GEODATA_COL,
                        geodata_center_col: str=GEODATA_CENTER_COL,
                        geo_cols: Optional[List[str]]=None,
                        kad_num_cols: Optional[List[str]]=None):
    if geo_cols is None:
        geo_cols = GEO_COLS
    if kad_num_cols is None:
        kad_num_cols = KAD_NUM_COLS

    data = data.copy()
    data = data.fillna('')
    data.columns = [col.upper() for col in data.columns]

    for col in geo_cols:
        data[col] = data[col].progress_apply(prepare_geo)

    for col in kad_num_cols:
        data[col] = data[col].progress_apply(prepare_kad_num)

    data[geodata_col] = data[geodata_col].progress_apply(create_geolist)
    data[geodata_center_col] = data[geodata_col].progress_apply(calc_polygon_centroid)

    return data

# %%
# print(calc_polygon_centroid([[0,0], [1,0], [1,1], [0,1]]),
#       'expect: [.5, .5]')
# print(calc_polygon_centroid([[0,1], [0,-1], [2,0]]),
#       'expect: [2/3, 0]')
# print(calc_polygon_centroid([[0,-1], [0,1], [2,0]]),
#       'expect: [2/3, 0]')
# print(calc_polygon_centroid([[0,0], [1,0], [1.5,0.5], [1,1], [0,1], [-.5,.5]]),
#       'expect: [.5, .5]')

# %%
data_mos_ru = pd.read_json('/Users/affernus/Downloads/data-29580-2022-10-20.json',
                            encoding='cp1251').dropna(axis=1, how='all')

# %%
prepared_dmr = prepare_data_mos_ru(data_mos_ru)
prepared_dmr['N_FIAS'] = prepared_dmr['N_FIAS'].str.upper()
# Out:
# 100%|██████████| 475401/475401 [00:13<00:00, 35968.55it/s]
# 100%|██████████| 475401/475401 [00:03<00:00, 139160.19it/s]
# 100%|██████████| 475401/475401 [00:01<00:00, 247404.59it/s]
# 100%|██████████| 475401/475401 [00:02<00:00, 221737.09it/s]
# 100%|██████████| 475401/475401 [00:11<00:00, 40002.72it/s]
#   0%|          | 0/475401 [00:00<?, ?it/s]/var/folders/7q/8vvk22jj58jd3fvwfg98269m0000gn/T/ipykernel_20979/1766981003.py:31: UserWarning: coords is empty
#   warn('coords is empty')
# 100%|██████████| 475401/475401 [00:19<00:00, 24047.20it/s]

# %%
prepared_dmr = prepared_dmr.replace({'': np.nan}).dropna(axis=1, how='all')

# %%
with pd.option_context('display.max_columns', None, 'display.max_colwidth', None):
    display(prepared_dmr.head(2))
    print(prepared_dmr.shape)
# Out:
#    GLOBAL_ID OBJ_TYPE ONTERRITORYOFMOSCOW  \
# 0  645622141   Здание                  да
# 1  645622142   Здание                  да
#
#                                                                                                                       ADDRESS  \
# 0        Российская Федерация, город Москва, внутригородская территория муниципальный округ Вешняки, Косинская улица, дом 26А
# 1  Российская Федерация, город Москва, внутригородская территория муниципальный округ Басманный, Гороховский переулок, дом 21
#
#                  SIMPLE_ADDRESS     UNOM                    P0            P1  \
# 0      Косинская улица, дом 26А  2102436  Российская Федерация  город Москва
# 1  Гороховский переулок, дом 21     5783  Российская Федерация  город Москва
#
#                                                          P2  \
# 0    внутригородская территория муниципальный округ Вешняки
# 1  внутригородская территория муниципальный округ Басманный
#
#                               P5                    P7 L1_TYPE L1_VALUE  \
# 0    муниципальный округ Вешняки       Косинская улица     дом      26А
# 1  муниципальный округ Басманный  Гороховский переулок     дом       21
#
#   L2_VALUE L3_VALUE                            ADM_AREA  \
# 0      NaN      NaN    Восточный административный округ
# 1      NaN      NaN  Центральный административный округ
#
#                         DISTRICT       NREG        DREG  \
# 0    муниципальный округ Вешняки  3303053.0  03.08.2004
# 1  муниципальный округ Басманный  1011856.0  13.07.2005
#
#                                  N_FIAS      D_FIAS               KAD_N  \
# 0  235212A3-01E8-4CC3-87D5-59F00C83898A  27.02.2012  77:03:0007004:1064
# 1  533D296D-1ECC-49EA-9156-DCFA8E38E4D8  27.02.2012  77:01:0003010:1018
#
#                KAD_ZU              KLADR  \
# 0  77:03:0007004:6443  77000000000040000
# 1  77:01:0003010:4146  77000000000112200
#
#                                        TDOC      NDOC        DDOC  \
# 0  Распоряжение префектуры АО города Москвы  875-В-РП  28.07.2004
# 1  Распоряжение префектуры АО города Москвы    3026-р  04.07.2005
#
#       ADR_TYPE    VID                SOSTAD        STATUS  \
# 0  Официальный  Адрес  Зарегистрирован в АР  Внесён в ГКН
# 1  Официальный  Адрес  Зарегистрирован в АР  Внесён в ГКН
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             GEODATA  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [[37.8279504545784, 55.7176609928454], [37.8286195050135, 55.7174401927724], [37.8284661997432, 55.7172920310098], [37.8280404992056, 55.7174326150897], [37.8279795383341, 55.7174527408861], [37.8277971493706, 55.7175128293572], [37.8279504545784, 55.7176609928454]]
# 1  [[37.6682995208392, 55.7662431483298], [37.6683153361192, 55.7662161815465], [37.6682467711738, 55.7662023546956], [37.6682610223573, 55.7661821263411], [37.6681876684064, 55.7661660596898], [37.6681726244854, 55.7661871863933], [37.6681295710992, 55.7661782636006], [37.6681461617712, 55.7661463558389], [37.6680536825827, 55.7661285198332], [37.6680283160622, 55.7661572950872], [37.6678266067447, 55.7661162557855], [37.6677727488124, 55.7661881829886], [37.6677504217352, 55.7661828244461], [37.667709246984, 55.766240362676], [37.6679436471296, 55.766288544657], [37.6679270349883, 55.7663155115827], [37.6680322751771, 55.7663369247134], [37.6680496857547, 55.7663104048687], [37.6682649515806, 55.7663545688389], [37.668302916126, 55.7662916457961], [37.6683314068679, 55.7662484936784], [37.6682995208392, 55.7662431483298]]
#
#                              GEODATA_CENTER L3_TYPE L2_TYPE   P4   P6   P3  \
# 0   (37.828208360207746, 55.71747652735648)     NaN     NaN  NaN  NaN  NaN
# 1  (37.668037361143384, 55.766233199632005)     NaN     NaN  NaN  NaN  NaN
#
#    P90  P91
# 0  NaN  NaN
# 1  NaN  NaN
# (475401, 40)

# %%
houses_data_files = get_filenames_from_dir(
    '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/',
    mandatory_substr='csv')
display(houses_data_files)
# Out:
# ['/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_2.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_3.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_1.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_4.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_5.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_7.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_6.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_8.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_9.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_11.csv',
#  '/Users/affernus/Downloads/Сведения_об_объектах_жилищного_фонда_на_23-10-2022/Сведения по ОЖФ Москва г на 23-10-2022_10.csv']

# %%
houses_data_list = []
for hd in houses_data_files:
    houses_data_list.append(pd.read_csv(hd, delimiter=';', low_memory=False))
houses_data = pd.concat(houses_data_list, ignore_index=True).drop_duplicates().reset_index(drop=True)

# %%
houses_data['Глобальный уникальный идентификатор дома по ФИАС'] = houses_data['Глобальный уникальный идентификатор дома по ФИАС'].str.upper()

# %%
with pd.option_context('display.max_columns', None, 'display.max_colwidth', None):
    display(houses_data.head(5))
    print(houses_data.shape)
# Out:
#                                                                 Адрес ОЖФ  \
# 0   108809, Москва г, п. Марушкинское, д. Марушкино, ул. Строителей, д. 3
# 1  108809, Москва г, п. Марушкинское, д. Марушкино, ул. Строителей, д. 3А
# 2   108809, Москва г, п. Марушкинское, д. Марушкино, ул. Строителей, д. 4
# 3   108809, Москва г, п. Марушкинское, д. Марушкино, ул. Строителей, д. 4
# 4   108809, Москва г, п. Марушкинское, д. Марушкино, ул. Строителей, д. 6
#
#   Идентификационный код адреса дома в ГИС ЖКХ  \
# 0        f93a19c3-ffab-48b5-92c3-d10a49166a72
# 1        9e595cc4-fa15-4d22-bc17-380b691f47c1
# 2        281b5116-2cef-4364-a850-1bb102687bfa
# 3        281b5116-2cef-4364-a850-1bb102687bfa
# 4        855583f2-ce42-4ad0-9c9a-cfca34288c7f
#
#   Глобальный уникальный идентификатор дома по ФИАС  Код ОКТМО  \
# 0             F93A19C3-FFAB-48B5-92C3-D10A49166A72   45949000
# 1             9E595CC4-FA15-4D22-BC17-380B691F47C1   45949000
# 2             35F6CD9F-509B-4C92-839F-B03F70DE53E5   45949000
# 3             35F6CD9F-509B-4C92-839F-B03F70DE53E5   45949000
# 4             10860E59-E7D1-43C2-A19B-1856644E9B3C   45949000
#
#   Способ управления  ОГРН организации, осуществляющей управление домом  \
# 0         Не выбран                                                NaN
# 1         Не выбран                                                NaN
# 2         Не выбран                                                NaN
# 3         Не выбран                                                NaN
# 4         Не выбран                                                NaN
#
#    КПП организации, осуществляющей управление домом  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Наименование организации, осуществляющей управление домом Тип дома  \
# 0                                                       NaN    Жилой
# 1                                                       NaN    Жилой
# 2                                                       NaN    Жилой
# 3                                                       NaN    Жилой
# 4                                                       NaN    Жилой
#
#    Состояние  Общая площадь дома Жилая площадь в доме  \
# 0  Исправный               396.2                  NaN
# 1  Исправный               124.9                  NaN
# 2  Исправный               209.3                  NaN
# 3  Исправный               209.3                  NaN
# 4  Исправный               145.6                  NaN
#
#   Дом находится в собственности субъекта Российской Федерации и в полном объеме используется в качестве общежития  \
# 0                                                                                                               -
# 1                                                                                                               -
# 2                                                                                                               -
# 3                                                                                                               -
# 4                                                                                                               -
#
#   Дом находится в муниципальной собственности и в полном объеме используется в качестве общежития  \
# 0                                                                                               -
# 1                                                                                               -
# 2                                                                                               -
# 3                                                                                               -
# 4                                                                                               -
#
#   Тип общежития Тип помещения (блока) Дата сноса объекта  \
# 0             -                   NaN                NaN
# 1             -                   NaN                NaN
# 2             -                   NaN                NaN
# 3             -                   NaN                NaN
# 4             -                   NaN                NaN
#
#   Номер помещения (блока) Номер комнаты   Кадастровый номер  \
# 0                     NaN           NaN  50:26:0170402:2106
# 1                     NaN           NaN                 нет
# 2                     NaN           NaN    77:18:0170406:50
# 3                     NaN             1                 NaN
# 4                     NaN           NaN   77:18:0170406:388
#
#   Глобальный уникальный идентификатор дома  \
# 0     dc41973a-8cdd-4298-b7d7-365cd5b96a09
# 1     407142e2-e27c-4973-b614-7cd939e5a037
# 2     66eabcec-e02b-408e-9629-d17935b14399
# 3     66eabcec-e02b-408e-9629-d17935b14399
# 4     505249be-5ff4-4f7f-bfdc-222aab4cae19
#
#   Глобальный уникальный идентификатор помещения  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Глобальный уникальный идентификатор комнаты
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3        a18b5ed7-98d0-4364-960f-63720f8fee31
# 4                                         NaN
# (5161209, 23)

# %%
not_room = houses_data['Номер помещения (блока)'].isna() & houses_data['Номер комнаты'].isna()
houses_data_not_room = houses_data[not_room].dropna(axis=1, how='all')
print(houses_data_not_room.shape)
# Out:
# (68318, 18)

# %%
display(houses_data_not_room.head())
# Out:
#                                            Адрес ОЖФ  \
# 0  108809, Москва г, п. Марушкинское, д. Марушкин...
# 1  108809, Москва г, п. Марушкинское, д. Марушкин...
# 2  108809, Москва г, п. Марушкинское, д. Марушкин...
# 4  108809, Москва г, п. Марушкинское, д. Марушкин...
# 5  108809, Москва г, п. Марушкинское, д. Марушкин...
#
#   Идентификационный код адреса дома в ГИС ЖКХ  \
# 0        f93a19c3-ffab-48b5-92c3-d10a49166a72
# 1        9e595cc4-fa15-4d22-bc17-380b691f47c1
# 2        281b5116-2cef-4364-a850-1bb102687bfa
# 4        855583f2-ce42-4ad0-9c9a-cfca34288c7f
# 5        75f9b36c-5b8e-4c81-9215-b5fc4d462c37
#
#   Глобальный уникальный идентификатор дома по ФИАС  Код ОКТМО  \
# 0             F93A19C3-FFAB-48B5-92C3-D10A49166A72   45949000
# 1             9E595CC4-FA15-4D22-BC17-380B691F47C1   45949000
# 2             35F6CD9F-509B-4C92-839F-B03F70DE53E5   45949000
# 4             10860E59-E7D1-43C2-A19B-1856644E9B3C   45949000
# 5             DBC3B094-D0E1-4FC3-A5F7-044B88FC8124   45949000
#
#   Способ управления  ОГРН организации, осуществляющей управление домом  \
# 0         Не выбран                                                NaN
# 1         Не выбран                                                NaN
# 2         Не выбран                                                NaN
# 4         Не выбран                                                NaN
# 5         Не выбран                                                NaN
#
#    КПП организации, осуществляющей управление домом  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 4                                               NaN
# 5                                               NaN
#
#   Наименование организации, осуществляющей управление домом Тип дома  \
# 0                                                NaN           Жилой
# 1                                                NaN           Жилой
# 2                                                NaN           Жилой
# 4                                                NaN           Жилой
# 5                                                NaN           Жилой
#
#    Состояние  Общая площадь дома Жилая площадь в доме  \
# 0  Исправный               396.2                  NaN
# 1  Исправный               124.9                  NaN
# 2  Исправный               209.3                  NaN
# 4  Исправный               145.6                  NaN
# 5  Исправный               224.1                  NaN
#
#   Дом находится в собственности субъекта Российской Федерации и в полном объеме используется в качестве общежития  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 4                                                  -
# 5                                                  -
#
#   Дом находится в муниципальной собственности и в полном объеме используется в качестве общежития  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 4                                                  -
# 5                                                  -
#
#   Тип общежития Дата сноса объекта   Кадастровый номер  \
# 0             -                NaN  50:26:0170402:2106
# 1             -                NaN                 нет
# 2             -                NaN    77:18:0170406:50
# 4             -                NaN   77:18:0170406:388
# 5             -                NaN  50:26:0170402:2279
#
#   Глобальный уникальный идентификатор дома
# 0     dc41973a-8cdd-4298-b7d7-365cd5b96a09
# 1     407142e2-e27c-4973-b614-7cd939e5a037
# 2     66eabcec-e02b-408e-9629-d17935b14399
# 4     505249be-5ff4-4f7f-bfdc-222aab4cae19
# 5     dae214a7-d984-4c71-9c97-48215a5fa8bf

# %%
houses_data_not_room
# Out:
#                                                  Адрес ОЖФ  \
# 0        108809, Москва г, п. Марушкинское, д. Марушкин...
# 1        108809, Москва г, п. Марушкинское, д. Марушкин...
# 2        108809, Москва г, п. Марушкинское, д. Марушкин...
# 4        108809, Москва г, п. Марушкинское, д. Марушкин...
# 5        108809, Москва г, п. Марушкинское, д. Марушкин...
# ...                                                    ...
# 5160120          129323, Москва г, проезд. Лазоревый, д. 6
# 5160265          129323, Москва г, проезд. Лазоревый, д. 8
# 5160410          129323, Москва г, проезд. Русанова, д. 11
# 5160596  129323, Москва г, проезд. Русанова, д. 25, кор...
# 5161000          129323, Москва г, проезд. Русанова, д. 31
#
#         Идентификационный код адреса дома в ГИС ЖКХ  \
# 0              f93a19c3-ffab-48b5-92c3-d10a49166a72
# 1              9e595cc4-fa15-4d22-bc17-380b691f47c1
# 2              281b5116-2cef-4364-a850-1bb102687bfa
# 4              855583f2-ce42-4ad0-9c9a-cfca34288c7f
# 5              75f9b36c-5b8e-4c81-9215-b5fc4d462c37
# ...                                             ...
# 5160120        689fd70f-3055-4465-8190-21ccac493d57
# 5160265        ca25b32a-eb6b-4d25-9dc9-de2d32e321f7
# 5160410        e61605c6-439f-46ac-8feb-fe5faf478145
# 5160596        f87cae10-8731-4507-9184-f28ad94ee09a
# 5161000        3b980976-358d-40af-95a6-4a8dbeb0cdbe
#
#         Глобальный уникальный идентификатор дома по ФИАС  Код ОКТМО  \
# 0                   F93A19C3-FFAB-48B5-92C3-D10A49166A72   45949000
# 1                   9E595CC4-FA15-4D22-BC17-380B691F47C1   45949000
# 2                   35F6CD9F-509B-4C92-839F-B03F70DE53E5   45949000
# 4                   10860E59-E7D1-43C2-A19B-1856644E9B3C   45949000
# 5                   DBC3B094-D0E1-4FC3-A5F7-044B88FC8124   45949000
# ...                                                  ...        ...
# 5160120             689FD70F-3055-4465-8190-21CCAC493D57   45361000
# 5160265             CA25B32A-EB6B-4D25-9DC9-DE2D32E321F7   45361000
# 5160410             E61605C6-439F-46AC-8FEB-FE5FAF478145   45361000
# 5160596             F87CAE10-8731-4507-9184-F28AD94EE09A   45361000
# 5161000             3B980976-358D-40AF-95A6-4A8DBEB0CDBE   45361000
#
#         Способ управления  ОГРН организации, осуществляющей управление домом  \
# 0               Не выбран                                                NaN
# 1               Не выбран                                                NaN
# 2               Не выбран                                                NaN
# 4               Не выбран                                                NaN
# 5               Не выбран                                                NaN
# ...                   ...                                                ...
# 5160120                УО                                       1.087746e+12
# 5160265                УО                                       1.087746e+12
# 5160410                УО                                       5.167746e+12
# 5160596                УО                                       1.087746e+12
# 5161000                УО                                       1.087746e+12
#
#          КПП организации, осуществляющей управление домом  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 5160120                                       771601001.0
# 5160265                                       771601001.0
# 5160410                                       771601001.0
# 5160596                                       771601001.0
# 5161000                                       771601001.0
#
#         Наименование организации, осуществляющей управление домом  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# ...                                                    ...
# 5160120  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ УПРАВ...
# 5160265  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ УПРАВ...
# 5160410  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ УПРАВ...
# 5160596  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ УПРАВ...
# 5161000  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ УПРАВ...
#
#                 Тип дома  Состояние  Общая площадь дома Жилая площадь в доме  \
# 0                  Жилой  Исправный               396.2                  NaN
# 1                  Жилой  Исправный               124.9                  NaN
# 2                  Жилой  Исправный               209.3                  NaN
# 4                  Жилой  Исправный               145.6                  NaN
# 5                  Жилой  Исправный               224.1                  NaN
# ...                  ...        ...                 ...                  ...
# 5160120  Многоквартирный  Исправный              6892.7                 6892
# 5160265  Многоквартирный  Исправный              6892.9               6892.9
# 5160410  Многоквартирный  Исправный             13456.2               9437.4
# 5160596  Многоквартирный  Исправный             29049.2                21213
# 5161000  Многоквартирный  Исправный             24463.2                16565
#
#         Дом находится в собственности субъекта Российской Федерации и в полном объеме используется в качестве общежития  \
# 0                                                        -
# 1                                                        -
# 2                                                        -
# 4                                                        -
# 5                                                        -
# ...                                                    ...
# 5160120                                                  -
# 5160265                                                  -
# 5160410                                                  -
# 5160596                                                  -
# 5161000                                                  -
#
#         Дом находится в муниципальной собственности и в полном объеме используется в качестве общежития  \
# 0                                                        -
# 1                                                        -
# 2                                                        -
# 4                                                        -
# 5                                                        -
# ...                                                    ...
# 5160120                                                  -
# 5160265                                                  -
# 5160410                                                  -
# 5160596                                                  -
# 5161000                                                  -
#
#         Тип общежития Дата сноса объекта    Кадастровый номер  \
# 0                   -                NaN   50:26:0170402:2106
# 1                   -                NaN                  нет
# 2                   -                NaN     77:18:0170406:50
# 4                   -                NaN    77:18:0170406:388
# 5                   -                NaN   50:26:0170402:2279
# ...               ...                ...                  ...
# 5160120             -                NaN   77:02:0014011:1055
# 5160265             -                NaN   77:02:0014011:1056
# 5160410             -                NaN  77:02:0014011:13860
# 5160596             -                NaN  77:02:0014011:13149
# 5161000             -                NaN  77:02:0014011:14331
#
#         Глобальный уникальный идентификатор дома
# 0           dc41973a-8cdd-4298-b7d7-365cd5b96a09
# 1           407142e2-e27c-4973-b614-7cd939e5a037
# 2           66eabcec-e02b-408e-9629-d17935b14399
# 4           505249be-5ff4-4f7f-bfdc-222aab4cae19
# 5           dae214a7-d984-4c71-9c97-48215a5fa8bf
# ...                                          ...
# 5160120     9d85374a-7c36-4f60-8cdb-43edc2300929
# 5160265     d9596c10-41ba-4fb5-9da6-5fe8b03a8fb0
# 5160410     a87c74af-1983-4b25-9ae4-529044cf0fb6
# 5160596     21357c11-18f4-4487-8281-4324d6df4ba9
# 5161000     4615c33c-c2a3-4436-855f-ce966fe8c20d
#
# [68318 rows x 18 columns]

# %%
dmr_fias = set(prepared_dmr['N_FIAS'])
dmr_kadn = set(prepared_dmr['KAD_N'])

# %%
houses_data_fias = set(houses_data['Глобальный уникальный идентификатор дома по ФИАС'])
houses_data_kadn = set(houses_data['Кадастровый номер'])

# %%
houses_data_nr_fias = set(houses_data_not_room['Глобальный уникальный идентификатор дома по ФИАС'])
houses_data_nr_kadn = set(houses_data_not_room['Кадастровый номер'])

# %%
print('fias:', len(houses_data_fias), len(houses_data_nr_fias), len(dmr_fias))
print('kadn', len(houses_data_kadn), len(houses_data_nr_kadn), len(dmr_kadn))
# Out:
# fias: 68159 68159 420680
# kadn 2872463 47094 188325

# %%
print(len(houses_data_fias & dmr_fias), len(houses_data_kadn & dmr_kadn))
print(len(houses_data_nr_fias & dmr_fias), len(houses_data_nr_kadn & dmr_kadn))
# Out:
# 67262 36784
# 67262 36783

# %%
# house_data_merged = prepared_dmr.merge(
#     houses_data,
#     left_on=['N_FIAS'],
#     right_on=['Глобальный уникальный идентификатор дома по ФИАС'],
#     how='left'
#     )
